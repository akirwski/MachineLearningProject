# %%
#developper account
#https://developer.twitter.com/en/portal/products
#demo
#https://www.toptal.com/python/twitter-data-mining-using-python
#https://www.geeksforgeeks.org/python-tweepy-getting-the-text-of-a-tweet/
#https://tech-blog.rakus.co.jp/entry/20210910/twitter

# %%
# !pip install git+https://github.com/tweepy/tweepy.git
# Out:
# ...
#   Cloning https://github.com/tweepy/tweepy.git to /private/var/folders/6d/5spwrq5j2p3_ks1nplxt_dpr0000gn/T/pip-req-build-qus1hhr9
#   Running command git clone -q https://github.com/tweepy/tweepy.git /private/var/folders/6d/5spwrq5j2p3_ks1nplxt_dpr0000gn/T/pip-req-build-qus1hhr9
#   Resolved https://github.com/tweepy/tweepy.git to commit b6b8241d8df408a427a38d3b9a44837f07cfab32
# ...

# %%
import tweepy
consumer_key = "i6saeUoMGoMYnu5bdG5L0lVJD"
consumer_secret = "IKc2qo5Ha5tMcYbSZSsPYlYHsXYl5fuTq9M7ujIT6n7NT5zdac"
access_token = "1514668933508317202-5MxsLvDnqxVltHnOXd6iqOt42hBQAn"
access_token_secret = "OUqIpO8rHOOjYw5yWw7lrTOZrTcAynRuscGFIXbrH1TN7"
bearer_token = "AAAAAAAAAAAAAAAAAAAAALkBbgEAAAAANbe6qZF2D0GNxKZyzeoimVgggek%3D7DBZrWuvfGA1pQT8JtzII9EPqLm8d0b6bEPP7UGBwk5vkKCZgc"

# %%
import requests

client = tweepy.Client( bearer_token=bearer_token, 
                        consumer_key=consumer_key, 
                        consumer_secret=consumer_secret, 
                        access_token=access_token, 
                        access_token_secret=access_token_secret, 
                        return_type = requests.Response,
                        wait_on_rate_limit=True)

# %%
# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth)

# %%
#dir(tweepy)

# %%
id = 1467810672
status = api.get_status(id)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# /var/folders/6d/5spwrq5j2p3_ks1nplxt_dpr0000gn/T/ipykernel_11143/3295876591.py in <module>
#       1 id = 1467810672
# ----> 2 status = api.get_status(id)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/api.py in get_status(self, id, **kwargs)
#     894         https://developer.twitter.com/en/docs/twitter-api/v1/tweets/post-and-engage/api-reference/get-statuses-show-id
#     895         """
# --> 896         return self.request(
# ...

# %%
# Define query
query = 'from:scotthamilton -is:retweet'

# get max. 10 tweets
tweets = client.search_recent_tweets(query=query, 
                                    tweet_fields=['author_id', 'created_at'],
                                     max_results=100)

# %%
dir(tweets)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
tweets_dict = tweets.json() 
tweets_dict
# Out:
# {'meta': {'result_count': 0}}

# %%
import pandas as pd

# Save data as dictionary
tweets_dict = tweets.json() 

# Extract "data" value from dictionary
tweets_data = tweets_dict['data'] 

# Transform to pandas Dataframe
df = pd.json_normalize(tweets_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/6d/5spwrq5j2p3_ks1nplxt_dpr0000gn/T/ipykernel_11143/1161110895.py in <module>
#       5
#       6 # Extract "data" value from dictionary
# ----> 7 tweets_data = tweets_dict['data']
#       8
#       9 # Transform to pandas Dataframe
#
# KeyError: 'data'

# %%
df
# Out:
#                      id                created_at author_id  \
# 0   1514726980909948928  2022-04-14T22:07:09.000Z  44196397
# 1   1514725812544712708  2022-04-14T22:02:30.000Z  44196397
# 2   1514723388396392452  2022-04-14T21:52:52.000Z  44196397
# 3   1514723037060468742  2022-04-14T21:51:28.000Z  44196397
# 4   1514720245113577473  2022-04-14T21:40:23.000Z  44196397
# 5   1514718700674306052  2022-04-14T21:34:15.000Z  44196397
# 6   1514708354429456386  2022-04-14T20:53:08.000Z  44196397
# 7   1514702695332036610  2022-04-14T20:30:39.000Z  44196397
# 8   1514698036760530945  2022-04-14T20:12:08.000Z  44196397
# 9   1514686582745284651  2022-04-14T19:26:37.000Z  44196397
# 10  1514683079968931841  2022-04-14T19:12:42.000Z  44196397
# 11  1514681422212128770  2022-04-14T19:06:07.000Z  44196397
# 12  1514564966564651008  2022-04-14T11:23:21.000Z  44196397
# 13  1513288055146225671  2022-04-10T22:49:22.000Z  44196397
# 14  1513283265318191106  2022-04-10T22:30:20.000Z  44196397
# ...
