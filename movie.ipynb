# %%
### <font color='darkblue'> Data Understanding

# %%
import os
os.chdir('/Users/akiratachibana/Downloads/Classes/Business_Intelligence/Project/archive')


import numpy as np
import pandas as pd
import math

mv1 = pd.read_csv('movies.csv')
mv_meta = pd.read_csv('movies_metadata.csv')
mv1.head()
# Out:
# /Users/akiratachibana/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# ...

# %%
mv_meta.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
variables = mv1.columns

# %%
#change the name to title in mv1
mv1 = mv1.rename(columns={"name": "original_title"})

# %%
#drop missing data
mv1=mv1.dropna()
mv_meta=mv_meta.dropna()
mv1.shape
# Out:
# (5421, 15)

# %%
mv_meta.shape
# Out:
# (693, 24)

# %%
#merge mv_meta dataset and movie industry dataset
mv_meta = pd.read_csv('movies_metadata.csv')
merge1 = pd.merge(mv1, mv_meta, on='original_title', how='left')
# Out:
# /Users/akiratachibana/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
merge1 = merge1.dropna()
merge1.to_excel("output1.xlsx")
merge1["id"] = pd.to_numeric(merge1["id"])
merge1.id
# Out:
# 7       13207
# 48       1103
# 53      18823
# 63        699
# 64      11281
#         ...
# 6069      948
# 6070     2082
# 6213     1487
# 6221     8587
# 6222      812
# Name: id, Length: 413, dtype: int64

# %%
#merge merged dataset 1 and credits dataset
credits = pd.read_csv('credits.csv')
credits.id
# Out:
# 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45471    439050
# 45472    111109
# 45473     67758
# 45474    227506
# 45475    461257
# Name: id, Length: 45476, dtype: int64

# %%
merge2 = pd.merge(merge1, credits, on='id', how='left')
merge2.to_excel("output2.xlsx")

# %%
#merge merged dataset 2 and keywords dataset
keywords = pd.read_csv('keywords.csv')
merge3 = pd.merge(merge1, keywords, on='id', how='left')
merge3.to_excel("output3.xlsx")

# %%
(rows, columns) = mv1.shape

# %%
print("Rows : ", rows)
print("Columns : ", columns)
# Out:
# Rows :  5436
# Columns :  15

# %%
### <font color='darkblue'> Data Preparation

# %%
### <font color='darkblue'> Modeling

# %%
Question: "Which factor affects the movie score significantly?"

# %%
mv1 = mv1.iloc[:, 1:].values
variables = mv1.columns
df = pd.DataFrame(mv1, columns = varname[1:])
df.head()
#varname
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/6d/5spwrq5j2p3_ks1nplxt_dpr0000gn/T/ipykernel_1270/3297162661.py in <module>
#       1 mv1 = mv1.iloc[:, 1:].values
# ----> 2 varname=list(mv1.iloc[:,:].columns)
#       3 df = pd.DataFrame(mv1, columns = varname[1:])
#       4 df.head()
#       5 #varname
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
#move the score column to the first column
first_column = df.pop('score')
df.insert(0, 'score', first_column)
#set Y to score and X to other variables
Y = raw1[:,0]
X = raw1[:,1:-1]
df
# Out:
#      score     rating      genre  year                           released  \
# 0      8.4          R      Drama  1980      June 13, 1980 (United States)
# 1      5.8          R  Adventure  1980       July 2, 1980 (United States)
# 2      8.7         PG     Action  1980      June 20, 1980 (United States)
# 3      7.7         PG     Comedy  1980       July 2, 1980 (United States)
# 4      7.3          R     Comedy  1980      July 25, 1980 (United States)
# ...    ...        ...        ...   ...                                ...
# 5416   6.6          R     Action  2020   January 17, 2020 (United States)
# 5417   6.5         PG     Action  2020  February 14, 2020 (United States)
# 5418   5.6         PG  Adventure  2020   January 17, 2020 (United States)
# 5419   6.8         PG  Adventure  2020  February 21, 2020 (United States)
# 5420   6.8  Not Rated     Action  2020    August 28, 2020 (United States)
#
#           votes         director                   writer               star  \
# ...

# %%
### <font color='darkblue'> Model Comparison

# %%
### <font color='darkblue'> Summary

# %%
raw1 = raw0.iloc[:, 1:].values
Y = raw1.score
X = raw1[:,0:-1]
